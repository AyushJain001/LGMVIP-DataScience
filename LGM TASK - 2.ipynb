# %% [markdown]
# # Name-Ayush Jain

# %% [markdown]
# # Role- Data Science Internship

# %% [markdown]
# # TASK - 2

# %% [markdown]
# # Image to Pencil Sketch with Python

# %%
# !pip3 install opencv-python pillow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting opencv-python
#   Downloading opencv_python-4.5.4.60-cp39-cp39-win_amd64.whl (35.1 MB)
# Requirement already satisfied: pillow in c:\users\jaina\appdata\roaming\python\python39\site-packages (8.4.0)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\jaina\appdata\roaming\python\python39\site-packages (from opencv-python) (1.21.2)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.4.60

# %%
import cv2
import numpy as np
from PIL import Image 
from IPython.display import Image as display

# %%
image = Image.open('C:\pic2new.png')
print(image.size)
image1 = cv2.imread('C:\pic2new.png')
cv2.imwrite('C:\pic2new.png', image1)
display(filename='C:\pic2new.png')
# Out:
# (846, 743)

# %%
img = cv2.imread('C:\pic2new.png')
grayed = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(grayed)
cv2.imwrite('C:\pic2new.png', grayed)
display(filename='C:\pic2new.png')
# Out:
# [[ 15  13  13 ...  92  92  92]
#  [ 16  13  12 ...  93  92  92]
#  [ 20  15  13 ...  95  95  95]
#  ...
#  [ 74  77  73 ... 151 150 150]
#  [ 73  78  76 ... 150 150 150]
#  [ 72  78  83 ... 149 149 149]]

# %%
inverted = cv2.bitwise_not(grayed)
cv2.imwrite("inverted.png", inverted)
display(filename="inverted.png")

# %%
blurred = cv2.GaussianBlur(inverted, (15, 15), sigmaX=0, sigmaY=0)
cv2.imwrite("blurred.png", blurred)
display(filename="blurred.png")

# %%
def blend(x, y):
    return cv2.divide(x, 255 - y, scale=257)
final_result = blend(grayed, blurred)
cv2.imwrite("final.png", final_result)
display(filename="final.png")
